# %% [markdown]
# ### RL tutorial. Part 2.

# %% [markdown]
# In this tutorial we will learn how implement agents that keep track of the value of their actions and the state they are in. We will use 4 different agents:
# - Random agent.
# - SARSA agent.
# - Q-learning agent.
# - Q-learning agent with eligibility traces.

# %% [markdown]
# ### 0. Setting things up

# %% [markdown]
# Import the necessary libraries and define the functions we will use to plot the results.
#
# JUST RUN THE CELLS BELOW.

# %%
# Uncomment following lines to install
! pip install gym   # Install gym

# %%
import numpy as np
from gym import spaces
import matplotlib.pyplot as plt
from IPython.display import display, clear_output
import time

def plot_reward_per_episode(reward_per_episode, ax=None):
    """Plot the reward per episode"""
    # Plot rewards
    if ax is None:
        _, ax = plt.subplots(figsize=(6, 6))
        ax.set_title("Reward per episode")
        ax.set_xlabel("Episode")
        ax.set_ylabel("Total Reward")
    ax.plot(reward_per_episode)
    # plt.show()

def plot_q_table(agent, action_space, max=50):
    """Plot the Q-table"""
    # plot q_table
    f, ax = plt.subplots(ncols=2, nrows=2, figsize=(10, 10))
    ax = ax.flatten()
    # actions
    titles = ['Up', 'Right', 'Down', 'Left']
    for i_a, a in enumerate(ax):
        if i_a < len(action_space):
            # plot the q-table for each action with values between -50 and 50
            im = a.imshow(agent.get_q_table()[:, :, i_a], cmap='hot', vmin=-5, vmax=50)
            plt.colorbar(im, ax=a)
            a.set_title(titles[i_a])
    plt.show()

# %% [markdown]
# ### 1. Explore the Gridworld environment

# %% [markdown]
# We will train our agents to navigate a gridworld. The gridworld is a 2D grid of size 5x5. The agent can move in 4 directions: up, down, left and right. It receives a reward of 50 if it reaches the goal state, a reward of -2 if it hits an obstacle and a reward of -1 otherwise.
#
# The gridworld is implemented with a class that contains the following methods:
# - `__init__`: initializes the gridworld with a given size, a list of obstacles and a goal state (check the other input parameters).
# - `new_trial`: resets the state of the agent to the start position and the count of steps within the trial to zero.
# - `step`: takes an action as input and returns the next state, the reward and a dictionary with a boolean indicating if the trial is finished.
# - `render`: prints the gridworld with the current position of the agent.

# %%
class GridWorld():
    """
     GridWorld task.

    Args:
        size: int, size of the grid
        starts: list, list of tuples indicating the possible starting positions of the agent
        goal: tuple, goal position of the agent
        obstacles: list of tuples, positions of the obstacles
    """
    def __init__(self, size=5, starts=[(0, 0)], goal=(4, 4), obstacles=None,
                 max_steps_per_trial=50):
        # define the task parameters
        self.size = size
        self.starts = starts
        self.goal = goal
        self.obstacles = obstacles or []
        self.max_steps_per_trial = max_steps_per_trial
        # observation space
        self.observation_space = spaces.Box(-np.inf, np.inf,
                                            shape=(9,), dtype=np.float32)
        # action space
        self.action_space = spaces.Discrete(5)
        # rewards for reaching the goal (correct), not reaching the goal (fail) and hitting an obstacle
        self.rewards = {'correct': 50, 'obstacle': -2, 'fail': -10, 'step_cost': -1}
        self.position = self.starts[np.random.randint(len(self.starts))]
        # step within the trial
        self.t = 0
        self.trial = 0

    def new_trial(self, **kwargs):
        """
        new_trial() is called to generate the next trial when the previous trial ends.
        kwargs could be used to modify the goal or start positions.
        """
        self.t = 0
        self.trial += 1
        # select start position from the list of possible start positions
        self.position = self.starts[np.random.randint(len(self.starts))]

    def step(self, action):
        """
        step receives an action and returns:
            a new state (the new position of the agent)
            the reward associated with the action
            a dictionary with extra information:
                boolean indicating the end of the trial, info['new_trial']
        """
        self.t += 1
        new_trial = False
        # process action
        if action == 0:  # Move up
            candidate = (max(self.position[0] - 1, 0), self.position[1])
        elif action == 1:  # Move right
            candidate = (self.position[0], min(self.position[1] + 1, self.size - 1))
        elif action == 2:  # Move down
            candidate = (min(self.position[0] + 1, self.size - 1), self.position[1])
        elif action == 3:  # Move left
            candidate = (self.position[0], max(self.position[1] - 1, 0))

        # Updtate reward and position
        if candidate == self.goal:
            reward = self.rewards['correct']
            new_trial = True
            self.new_trial()
        elif candidate in self.obstacles:
            reward = self.rewards['obstacle']
        else:
            self.position = candidate
            reward = self.rewards['step_cost']

        # check time limit
        if self.t > self.max_steps_per_trial:
            new_trial = True
            reward = self.rewards['fail']
            self.new_trial()

        return self.position, reward, {'new_trial': new_trial}

    def render(self, ax=None):
        """
        Display position of the agent, obstacles and goal in a grid.
        """
        grid = np.zeros((self.size, self.size))
        grid[self.position] = 1  # agent's position marked with 1
        grid[self.goal] = 2  # goal position marked with 0.5
        for obstacle in self.obstacles:
            grid[obstacle] = -1
        # pad grid with -1
        grid = np.pad(grid, pad_width=1, mode='constant', constant_values=-1)
        if ax is None:
            _, ax = plt.subplots()
        ax.imshow(grid, vmin=-1, vmax=2, cmap='hot')
        # remove xtiks and yticks
        ax.set_xticks([])
        ax.set_yticks([])

# %% [markdown]
# #### 1.1. Define gridworld parameters

# %% [markdown]
# Let's define the default parameters for the gridworld:
# - `grid_size`: size of the gridworld.
# - `starts`: initial position of the agent. Note that this can be a list of possible initial positions.
# - `goal`: goal position of the agent.
# - `obstacles`: list of obstacles.
# - `max_steps_per_trial`: maximum number of steps per trial.

# %%
grid_size = 5
starts = [(0, 0)]
goal = (grid_size - 1, grid_size - 1)
obstacles = [(x, grid_size//2) for x in range(grid_size-2)]
max_steps_per_trial = 20

# %% [markdown]
# #### 1.2. Play with the environment

# %% [markdown]
# Check you understand the gridworld task. Suggestions:
# - change the size of the grid and see what happens.
# - change the start and goal locations.
# - change the obstacles to be randomly placed blocks.
# - ...

# %%
# INSTRUCTION 1. Explore the different parameters of the GridWorld task
grid_size_test = 5
start_test = [(0, 0)]
goal_test = (grid_size_test - 1, grid_size_test - 1)
obstacles_test = [(x, grid_size_test//2) for x in range(grid_size_test-2)]
max_steps_per_trial_test = 20
env = GridWorld(size=grid_size_test, starts=start_test, goal=goal_test, obstacles=obstacles_test, max_steps_per_trial=max_steps_per_trial_test)
# action names
actions = ['up', 'right', 'down', 'left']
# INSTRUCTION 2. Define an action plan to reach the goal by hand (Note that the actions correspond to codes 0,1,2,3)
good_path = [2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2]
# number of rows and columns is the root of the number of actions
nrows = int(np.sqrt(len(good_path)))
ncols = nrows+1
f, ax = plt.subplots(figsize=(10, 10), nrows=nrows, ncols=ncols)
ax = ax.flatten()
for i_a, action in enumerate(good_path):
    env.step(action)
    env.render(ax=ax[i_a])
    # remove xtiks and yticks
    ax[i_a].set_xticks([])
    ax[i_a].set_yticks([])
    # add title
    ax[i_a].set_title(actions[action])
# remove last axis
ax[-1].axis('off')
# Out:
# /home/manuel/anaconda3/lib/python3.7/site-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# (0.0, 1.0, 0.0, 1.0)

# %% [markdown]
# ### 2. Random Agent

# %% [markdown]
# Now that we understand the gridworld environment, let's implement our first agent. We will start by implementing a random agent with a class.
#
# As you can see, the random agent does not care about the environment and choses a random action from the available ones. Pay attention to the structure of the class, as we will use the same structure for the other agents.

# %%
class Random:
    """ 
    Random agent. 
    The random agent selects an action at random from the action space and does not try to learn anything (don't be like the random agent!)
    """
    def __init__(self, action_space):
        self.action_space = action_space
    # Side note: **kwargs is a dictionary of arguments that allows us to pass an arbitrary number of arguments to the function. We use it here
    # to make the function compatible with the train_agent function below.
    def get_action(self, **kwargs):
        return np.random.choice(self.action_space)
    def learn(self, **kwargs):
        pass

# %% [markdown]
# ### 3. Training function

# %% [markdown]
# This is the function we will use to train all our agents. It establishes the communication between the agent and the gridworld.
#
# Think of what the gridworld needs from the agent to update the state and what the agent needs from the gridworld to act and learn to make better decisions.

# %%
def train_agent(agent, grid_size=5, starts=[(0, 0)], goal=(4, 4), obstacles=[(x, 3) for x in range(3)],
                max_num_tr=100, verbose=False, max_steps_per_trial=50, render_flag=False, learn_flag=True):
    """
    Create gridWorld and agent, and train agent for a number of trials.

    Args:
        agent: agent to train
        grid_size: int, size of the grid
        start: tuple, starting position of the agent
        goal: tuple, goal position for the agent
        obstacles: list of tuples, positions of the obstacles
        max_num_tr: int, maximum number of trials
        verbose: bool, whether to display the environment
        max_steps_per_trial: int, maximum number of steps per trial
        render_flag: bool, whether to render the environment
        learn_flag: bool, whether the agent should learn
    """
    # Create grid world
    env = GridWorld(size=grid_size, starts=starts, goal=goal, obstacles=obstacles, max_steps_per_trial=max_steps_per_trial)

    # First action of the agent. In order to act the agent needs to know the state of the environment.
    action = agent.get_action(state=env.position)
    state, _, _ = env.step(action)
    reward_per_episode = []
    total_reward = 0
    while env.trial < max_num_tr:
        # Get the next action from the agent.
        action = agent.get_action(state=state)
        next_state, reward, info = env.step(action)
        # Learn from the experience. In order to learn the agent needs to know the previous state, the action taken,
        # the reward obtained and the new state after the action.
        if learn_flag:
            agent.learn(state=state, action=action, reward=reward, next_state=next_state)
        state = next_state
        if verbose and env.trial % 100 == 0 and env.t == 0:
            print(f"Trial: {env.trial + 1}, Step: {env.t + 1}, State: {state}, Action: {action}, Next State: {next_state},\
                    Reward: {reward}, Total Reward: {total_reward}, New trial: {info['new_trial']}")
        if render_flag:
            # render and wait 0.1 seconds
            clear_output(wait=True)
            env.render()
            plt.show()
            time.sleep(0.1)
        total_reward += reward
        if info['new_trial']: # check if the trial has ended
            reward_per_episode.append(total_reward)
            total_reward = 0
    return reward_per_episode

# %% [markdown]
# #### 3.1. Run the random agent

# %% [markdown]
# Let's run the random agent and see how it performs. Since this agent does not learn, we will set the number of trials to 10 and visualize what it does in each step.

# %%
# The action space is a list of integers with the actions that the agent can take: 0, 1, 2, 3, corresponding to up, right, down, left.
action_space = [0, 1, 2, 3]
max_num_tr = 10
verbose = True
render_flag = True
learn_flag = True  # note that this is actually not relevant for the random agent
agent = Random(action_space=action_space)
reward_per_episode_random =\
      train_agent(agent=agent, grid_size=grid_size, starts=starts, goal=goal,
                  obstacles=obstacles, max_num_tr=max_num_tr, render_flag=render_flag,
                  verbose=verbose, max_steps_per_trial=max_steps_per_trial)
plot_reward_per_episode(reward_per_episode_random)

# %% [markdown]
# As you see, the random agent does not do great and it is a bit frustrating to see it so close to the goal and not reaching it. If only it could learn...
#
# Let's see if we can do better with a SARSA agent!

# %% [markdown]
# ### 4. SARSA Agent

# %% [markdown]
# The state-action-reward-state-action (SARSA) agent learns the value of its actions by following the policy it has learned so far. It is an on-policy method. The formula of the learning rule is:
# $$Q(s_t,a_t) \leftarrow Q(s_t,a_t) + \alpha \left[ r_{t+1} + \gamma Q(s_{t+1},a_{t+1}) - Q(s_t,a_t) \right]$$

# %% [markdown]
# #### 4.1. Implement a random SARSA agent

# %% [markdown]
# We will first implement a random SARSA agent. This agent will learn the value of its actions but will still choose a random action from the available ones.

# %%
class RandomSARSAAgent:
    def __init__(self, action_space, state_space, alpha=0.1, gamma=0.9, epsilon=1):
        self.action_space = action_space
        self.state_space = state_space
        self.alpha = alpha
        self.gamma = gamma
        self.epsilon = epsilon
        self.q_table = np.random.rand(self.state_space[0], self.state_space[1], len(self.action_space))

    # INSTRUCTION 3: return the agent's action.
    def get_action(self, state):
        # INSTRUCTION 3.1: implement random policy
        
    # INSTRUCTION 4: learn from experience
    def learn(self, state, action, reward, next_state):
        # INSTRUCTION 4.1: get old value from the q-table
        
        # INSTRUCTION 4.2: get action from the q-table
        
        # INSTRUCTION 4.3: get the maximum value from the q-table for the next state and action
        
        # INSTRUCTION 4.4: update the q-table
        
        
    def get_q_table(self):
        return self.q_table
# Out:
#   File "<ipython-input-9-4dc8ceeacac0>", line 15
#     def learn(self, state, action, reward, next_state):
#       ^
# IndentationError: expected an indented block

# %% [markdown]
# ##### 4.1.1. Run the random SARSA agent

# %%
max_num_tr = 1000
state_space = (grid_size, grid_size)
epsilon = 0.1
agent = RandomSARSAAgent(action_space=action_space, state_space=state_space, epsilon=epsilon)
reward_per_episode_randomsarsa =\
      train_agent(agent=agent, grid_size=grid_size, starts=starts, goal=goal,
                  obstacles=obstacles, max_num_tr=max_num_tr,
                  verbose=verbose, max_steps_per_trial=max_steps_per_trial)
# plot_reward_per_episode(reward_per_episode_sarsa) you can plot the reward per episode if you want, but it will not be very informative since the agent is not learning
plot_q_table(agent, action_space)
# Out:
# /home/manuel/anaconda3/lib/python3.7/site-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# Trial: 101, Step: 1, State: (0, 0), Action: 3, Next State: (0, 0),                    Reward: -10, Total Reward: -23, New trial: True
# Trial: 201, Step: 1, State: (0, 0), Action: 1, Next State: (0, 0),                    Reward: -10, Total Reward: -22, New trial: True
# Trial: 301, Step: 1, State: (0, 0), Action: 1, Next State: (0, 0),                    Reward: -10, Total Reward: -20, New trial: True
# Trial: 401, Step: 1, State: (0, 0), Action: 1, Next State: (0, 0),                    Reward: -10, Total Reward: -23, New trial: True
# Trial: 501, Step: 1, State: (0, 0), Action: 3, Next State: (0, 0),                    Reward: -10, Total Reward: -25, New trial: True
# Trial: 601, Step: 1, State: (0, 0), Action: 1, Next State: (0, 0),                    Reward: -10, Total Reward: -22, New trial: True
# Trial: 701, Step: 1, State: (0, 0), Action: 2, Next State: (0, 0),                    Reward: -10, Total Reward: -23, New trial: True
# Trial: 801, Step: 1, State: (0, 0), Action: 3, Next State: (0, 0),                    Reward: -10, Total Reward: -24, New trial: True
# Trial: 901, Step: 1, State: (0, 0), Action: 1, Next State: (0, 0),                    Reward: -10, Total Reward: -24, New trial: True
# Trial: 1001, Step: 1, State: (0, 0), Action: 0, Next State: (0, 0),                    Reward: -10, Total Reward: -22, New trial: True

# %% [markdown]
# Although the Random SARSA agent would never survive in a wild gridworld, it learns a very accurate value for each action and state in the gridworld. This is because it **randomly** visits each state-action pair many times.
#
# Check the values of the actions. Do they make sense?

# %% [markdown]
# #### 4.2. Implement an e-greedy SARSA agent
#
# We will now implement the whole agent, which will learn a good-enough q-table so it can choose the best action in each state. Remember that following an e-greedy policy means choosing the best action with probability 1-epsilon and a random action with probability epsilon.
#
# COPY AND PASTE THE CODE FROM THE PREVIOUS CELL BELOW AND MODIFY IT.

# %% [markdown]
# ##### 4.2.1. Run the e-greedy SARSA agent

# %%
state_space = (grid_size, grid_size)
epsilon = 0.1
agent = SARSAAgent(action_space=action_space, state_space=state_space, epsilon=epsilon)
reward_per_episode_egreedysarsa =\
      train_agent(agent=agent, grid_size=grid_size, starts=starts, goal=goal,
                  obstacles=obstacles, max_num_tr=max_num_tr,
                  verbose=verbose, max_steps_per_trial=max_steps_per_trial)
plot_reward_per_episode(reward_per_episode_egreedysarsa)
plot_q_table(agent, action_space)
# Out:
# Trial: 101, Step: 1, State: (0, 0), Action: 1, Next State: (0, 0),                    Reward: 50, Total Reward: -7, New trial: True
# Trial: 201, Step: 1, State: (0, 0), Action: 1, Next State: (0, 0),                    Reward: 50, Total Reward: -15, New trial: True
# Trial: 301, Step: 1, State: (0, 0), Action: 1, Next State: (0, 0),                    Reward: 50, Total Reward: -11, New trial: True
# Trial: 401, Step: 1, State: (0, 0), Action: 1, Next State: (0, 0),                    Reward: 50, Total Reward: -9, New trial: True
# Trial: 501, Step: 1, State: (0, 0), Action: 1, Next State: (0, 0),                    Reward: 50, Total Reward: -7, New trial: True
# Trial: 601, Step: 1, State: (0, 0), Action: 1, Next State: (0, 0),                    Reward: 50, Total Reward: -7, New trial: True
# Trial: 701, Step: 1, State: (0, 0), Action: 1, Next State: (0, 0),                    Reward: 50, Total Reward: -9, New trial: True
# Trial: 801, Step: 1, State: (0, 0), Action: 1, Next State: (0, 0),                    Reward: 50, Total Reward: -10, New trial: True
# Trial: 901, Step: 1, State: (0, 0), Action: 1, Next State: (0, 0),                    Reward: 50, Total Reward: -7, New trial: True
# Trial: 1001, Step: 1, State: (0, 0), Action: 1, Next State: (0, 0),                    Reward: 50, Total Reward: -7, New trial: True

# %% [markdown]
# It seems the e-greddy SARSA agent is doing a better job than the random SARSA agent, but how about the q-tables? Do they make complete sense? What do you think is happening?
# (hint: increase the epsilon value and see what happens).

# %% [markdown]
# #### 4.2. 2. See what the agent has learned

# %% [markdown]
# Let's check the policy the agent has learned. We set the learn_flag to zero and run it for 10 trials.

# %%
reward_per_episode_sarsa =\
      train_agent(agent=agent, grid_size=grid_size, starts=starts, goal=goal,
                  obstacles=obstacles, max_num_tr=10, learn_flag=False, render_flag=True,
                  verbose=verbose, max_steps_per_trial=max_steps_per_trial)

# %% [markdown]
# What differences do you see between the random SARSA agent and the e-greedy SARSA agent? Who would you trust more to navigate the gridworld? And to know about the gridworld?

# %% [markdown]
# #### 4.3. Implement a softmax SARSA agent
#
# We will now implement a softmax agent, which will choose the actions using a softmax function.
#
# COPY AND PASTE THE CODE FROM THE PREVIOUS CELL BELOW AND MODIFY IT.

# %% [markdown]
# ##### 4.3.1. Run the softmax SARSA agent

# %%
state_space = (grid_size, grid_size)
epsilon = 0.1
agent = SARSASoftmaxAgent(action_space=action_space, state_space=state_space, epsilon=epsilon)
reward_per_episode_softmaxsarsa =\
      train_agent(agent=agent, grid_size=grid_size, starts=starts, goal=goal,
                  obstacles=obstacles, max_num_tr=max_num_tr,
                  verbose=verbose, max_steps_per_trial=max_steps_per_trial)
plot_reward_per_episode(reward_per_episode_softmaxsarsa)
plot_q_table(agent, action_space)
# Out:
# Trial: 101, Step: 1, State: (0, 0), Action: 1, Next State: (0, 0),                    Reward: 50, Total Reward: -9, New trial: True
# Trial: 201, Step: 1, State: (0, 0), Action: 1, Next State: (0, 0),                    Reward: 50, Total Reward: -8, New trial: True
# Trial: 301, Step: 1, State: (0, 0), Action: 1, Next State: (0, 0),                    Reward: 50, Total Reward: -7, New trial: True
# Trial: 401, Step: 1, State: (0, 0), Action: 1, Next State: (0, 0),                    Reward: 50, Total Reward: -9, New trial: True
# Trial: 501, Step: 1, State: (0, 0), Action: 1, Next State: (0, 0),                    Reward: 50, Total Reward: -7, New trial: True
# Trial: 601, Step: 1, State: (0, 0), Action: 1, Next State: (0, 0),                    Reward: 50, Total Reward: -9, New trial: True
# Trial: 701, Step: 1, State: (0, 0), Action: 1, Next State: (0, 0),                    Reward: 50, Total Reward: -7, New trial: True
# Trial: 801, Step: 1, State: (0, 0), Action: 1, Next State: (0, 0),                    Reward: 50, Total Reward: -7, New trial: True
# Trial: 901, Step: 1, State: (0, 0), Action: 1, Next State: (0, 0),                    Reward: 50, Total Reward: -9, New trial: True
# Trial: 1001, Step: 1, State: (0, 0), Action: 1, Next State: (0, 0),                    Reward: 50, Total Reward: -7, New trial: True

# %% [markdown]
# Let's move now to the Q-learning agent! We will later compare all our agents and see which one performs better.

# %% [markdown]
# ### 5. Q-Learning Agent

# %% [markdown]
# The Q-learning agent uses an off-line policy to learn about the environment. As the SARSA algorithm, it works by maintaining a table of action-value estimates Q(s, a). The difference between the two is in the way they update the q-table. The Q-learning agent uses the following learning rule:
#
# $$Q(s_t,a_t) \leftarrow Q(s_t,a_t) + \alpha \left[ r_{t+1} + \gamma \max_a Q(s_{t+1},a) - Q(s_t,a_t) \right]$$
#
# Thus, the Q-learning agent uses the q-value of the **best** action in the next state, instead of choosing an action and using the q-value of the resulting next state.

# %%
class QLearningAgent:
    def __init__(self, action_space, state_space, alpha=0.1, gamma=0.9, epsilon=0.1):
        self.action_space = action_space
        self.state_space = state_space
        self.alpha = alpha
        self.gamma = gamma
        self.epsilon = epsilon
        self.q_table = np.random.rand(self.state_space[0], self.state_space[1], len(self.action_space))
    def get_action(self, state):
        # Implement epsilon-greedy policy
        if state is None or np.random.rand() < self.epsilon:  # Explore: select a random action
            return np.random.choice(self.action_space)
        else:                                # Exploit: select the action with max value (greedy policy)
            return np.argmax(self.q_table[state[0], state[1]])
    # INSTRUCTION 7: learn from experience
    def learn(self, state, action, reward, next_state):
        # INSTRUCTION 7.1: get old value from the q-table
        
        # INSTRUCTION 7.2: get the maximum value from the q-table for the next state and action. This is different from SARSA!
        
        # INSTRUCTION 7.3: update the q-table
        
    def get_q_table(self):
        return self.q_table

# %% [markdown]
# #### 5.1. Run the Q-learning agent

# %%
state_space = (grid_size, grid_size)
epsilon = 0.1
agent = QLearningAgent(action_space=action_space, state_space=state_space, epsilon=epsilon)

reward_per_episode_ql =\
      train_agent(agent=agent, grid_size=grid_size, starts=starts, goal=goal,
                  obstacles=obstacles, max_num_tr=max_num_tr,
                  verbose=verbose, max_steps_per_trial=max_steps_per_trial)
plot_reward_per_episode(reward_per_episode_ql)
plot_q_table(agent, action_space)
# Out:
# /home/manuel/anaconda3/lib/python3.7/site-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# Trial: 101, Step: 1, State: (0, 0), Action: 2, Next State: (0, 0),                    Reward: 50, Total Reward: -11, New trial: True
# Trial: 201, Step: 1, State: (0, 0), Action: 2, Next State: (0, 0),                    Reward: 50, Total Reward: -11, New trial: True
# Trial: 301, Step: 1, State: (0, 0), Action: 2, Next State: (0, 0),                    Reward: 50, Total Reward: -9, New trial: True
# Trial: 401, Step: 1, State: (0, 0), Action: 2, Next State: (0, 0),                    Reward: 50, Total Reward: -7, New trial: True
# Trial: 501, Step: 1, State: (0, 0), Action: 2, Next State: (0, 0),                    Reward: 50, Total Reward: -7, New trial: True
# Trial: 601, Step: 1, State: (0, 0), Action: 2, Next State: (0, 0),                    Reward: 50, Total Reward: -8, New trial: True
# Trial: 701, Step: 1, State: (0, 0), Action: 2, Next State: (0, 0),                    Reward: 50, Total Reward: -9, New trial: True
# Trial: 801, Step: 1, State: (0, 0), Action: 2, Next State: (0, 0),                    Reward: 50, Total Reward: -7, New trial: True
# Trial: 901, Step: 1, State: (0, 0), Action: 2, Next State: (0, 0),                    Reward: 50, Total Reward: -8, New trial: True
# Trial: 1001, Step: 1, State: (0, 0), Action: 2, Next State: (0, 0),                    Reward: 50, Total Reward: -7, New trial: True

# %% [markdown]
# ### 6. Q-Learning Agent with elegibility trace

# %% [markdown]
# Finally, we will implement a Q-learning agent with elegibility traces. The formula of the learning rule is:
# $$Q(s_t,a_t) \leftarrow Q(s_t,a_t) + \alpha \delta_t e_t$$
#
# where $\delta_t = r_{t+1} + \gamma \max_a Q(s_{t+1},a) - Q(s_t,a_t)$ and $e_t$ is the elegibility trace. The elegibility trace is updated as follows:
#
# $$e_t = \gamma \lambda e_{t-1} + \mathbb{1}(s_t,a_t)$$
#
# where $\mathbb{1}(s_t,a_t)$ is the indicator function that is 1 if the agent is in state $s_t$ and takes action $a_t$ and 0 otherwise.

# %%
class QLearningAgent_with_eligibility:
    def __init__(self, action_space, state_space, alpha=0.1, gamma=0.9, epsilon=0.1, lambda_=0.9):
        self.action_space = action_space
        self.state_space = state_space
        self.alpha = alpha
        self.gamma = gamma
        self.epsilon = epsilon
        self.lambda_ = lambda_
        self.q_table = np.random.rand(self.state_space[0], self.state_space[1], len(self.action_space))
        self.eligibility_trace = np.zeros((self.state_space[0], self.state_space[1]))
    def get_action(self, state):
        if state is None or np.random.rand() < self.epsilon:  # Explore: select a random action
            return np.random.choice(self.action_space)
        else:  # Exploit: select the action with max value (greedy policy)
            return np.argmax(self.q_table[state[0], state[1]])
    # INSTRUCTION 8: learn from experience
    def learn(self, state, action, reward, next_state):
        # INSTRUCTION 8.1: get old value from the q-table
        
        # INSTRUCTION 8.2: update eligibility trace
        
        # INSTRUCTION 8.3: update eligibility trace for the current state and action
        
        # INSTRUCTION 8.4: get the maximum value from the q-table for the next state and action
        

        # INSTRUCTION 8.5: calculate the temporal difference delta
        

        # INSRTUCTION 8.6: Update Q-value using eligibility trace
        
    def get_q_table(self):
        return self.q_table

# %% [markdown]
# #### 6.1. Run the Q-learning agent with elegibility trace

# %%
state_space = (grid_size, grid_size)
epsilon = 0.7
alpha = 0.1
gamma = 0.9
lambda_= 0.9
agent = QLearningAgent_with_eligibility(action_space=action_space, state_space=state_space, epsilon=epsilon,
                                        alpha=alpha, gamma=gamma, lambda_=lambda_)
reward_per_episode_et =\
      train_agent(agent=agent, grid_size=grid_size, starts=starts, goal=goal,
                  obstacles=obstacles, max_num_tr=max_num_tr,
                  verbose=verbose, max_steps_per_trial=max_steps_per_trial)
plot_reward_per_episode(reward_per_episode_et)
plot_q_table(agent, action_space)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-e660b3d2e2e7> in <module>
# ----> 1 state_space = (grid_size, grid_size)
#       2 epsilon = 0.7
#       3 alpha = 0.1
#       4 gamma = 0.9
#       5 lambda_= 0.9
#
# NameError: name 'grid_size' is not defined

# %% [markdown]
# ### 7. Compare the agents

# %% [markdown]
# We will now compare the learning of the different agents.

# %%
# create figure
f, ax = plt.subplots(figsize=(6, 6))
plot_reward_per_episode(reward_per_episode_randomsarsa, ax=ax)
plot_reward_per_episode(reward_per_episode_egreedysarsa, ax=ax)
plot_reward_per_episode(reward_per_episode_softmaxsarsa, ax=ax)
plot_reward_per_episode(reward_per_episode_ql, ax=ax)
plot_reward_per_episode(reward_per_episode_et, ax=ax)
# add legend to ax
ax.legend(['Random-SARSA', 'e-greedy SARSA', 'softmax SARSA', 'Q-Learning', 'Q-Learning with Eligibility Trace'])
ax.set_title("Reward per episode")
ax.set_xlabel("Episode")
ax.set_ylabel("Total Reward")
# Out:
# Text(0, 0.5, 'Total Reward')

# %% [markdown]
# Which one is better? Which one did you expect to be better? Can you think of ways to increase the difference between the agents? (hint: change the gridworld parameters: size, obstacles, provide a list of possible starting positions...).
